# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## HW1- problem 2- Support Vector Machine (100 + 10 pts)

# %% [markdown]
# ### Please fill this part
#
#
# 1.   Full Name: Farhad Fallah
# 2.   Student Number: 97102214
#
#
# *You are just allowded to change those parts that start with "TO DO". Please do not change other parts.*
#
# *It is highly recommended to read each codeline carefully and try to understand what it exactly does. Best of luck and have fun!*

# %%
# You are not allowed to import other packages.
import numpy as np
import pandas as pd
 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC

import cvxopt

# %% [markdown]
# #### About the Data:
# Heart diseases, also known as [Cardiovascular diseases (CVDs)](https://en.wikipedia.org/wiki/Cardiovascular_disease), are the first cause of death worldwide, taking an estimated 17.9 million lives each year which is about 32% of all deaths all over the world.
#
# In the present HomeWork, we are going to implement Support Vector Machines (SVM) algorithm that determines which patient is in danger and which is not.
#
# For this perpose, `Heart_Disease_Dataset.csv` file can be used that is attached to the HomeWork folder. Use `Dataset_Description.pdf` for more detail.

# %%
df = pd.read_csv("./data/Heart_Disease_Dataset.csv") 
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# 2                       0            1              98                0
# 3                       0            0             108                1
# 4                       0            0             122                0
# ...                   ...          ...             ...              ...
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 1         1.0         2       1
# 2         0.0         1       0
# 3         1.5         2       1
# 4         0.0         1       0
# ...       ...       ...     ...
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# 1189      0.0         1       0
#
# [1190 rows x 12 columns]

# %% [markdown]
# ### Pre-Processing - (40 pts)

# %% [markdown]
# #### Exploratory Data Analysis (EDA):
# In statistics, exploratory data analysis is an approach to analyze datasets to summarize their main characteristics, often using statistical graphics and other data visualization methods.
#
# This is a general approach that should be applied when you encounter a dataset.

# %%
###############################################################################
## TODO: Find the shape of the dataset.                                      ##
###############################################################################
shape = df.shape
print("shape of dataset is: " , shape)

###############################################################################
## TODO: Check if there is missing entries in the dataset columnwise.        ##
###############################################################################
missings = df.isna().sum().sum()
if missings:
    print("this dataset has missing value")
else:
     print("this dataset has not missing value")


###############################################################################
## TODO: Check whether the dataset is balanced or not.                       ##
## If the difference between 2 classes was less than 100 for our dataset,    ##
## it is called "ballanced".                                                 ##
###############################################################################
target1 = len(df[df.target==1])
target0 = len(df[df.target==0])
dif = abs(target1 - target0)
if dif>100:
    print("ballanced: False")
else :
     print("ballanced: True")


###############################################################################
## TODO: plot the age distirbution and gender distrbution for both normal    ##
## and heart diseses patients.(4 plots)                                      ##
###############################################################################
print("--------------------- Plots --------------------------")
normals = df[df.target == 0]
patients = df[df.target == 1]
fig,axs = plt.subplots(2,2)
fig.set_size_inches(15,15)
plt.subplot(2,2,1)
plt.title('age distribution for patients')
patients['age'].hist(bins = 40,histtype='bar', ec='black')
plt.subplot(2,2,2)
plt.title('gender distribution for patients')
patients['sex'].hist()
plt.legend(['1:male 0:female'])

plt.subplot(2,2,3)
plt.title('age distribution for normals')
normals['age'].hist(bins = 40,histtype='bar', ec='black')
plt.subplot(2,2,4)
plt.title('gender distribution for normals')
normals['sex'].hist(histtype='bar', ec='black')
plt.legend(['1:male 0:female'])
# Out:
# shape of dataset is:  (1190, 12)
# this dataset has not missing value
# ballanced: True
# --------------------- Plots --------------------------

# %% [markdown]
# #### Question 1: What do you conclude from the plots?
# #### Answer:

# %% [markdown]
# با مشاهده نمودار ها میبینیم که توزیع بیماری در سنین مختلف تقریبا به صورت زنگوله ای است و پیک افراد بیمار و سالم تقریبا 10 با هم فرق دارد
# همچنین با مشاهده نمودار تفکیک جنسیتی میبینیم که اولا کیس های آقای دیتا ست بیشتر از کیس های خانم هستند و ثانیا نسبتا زنان سالم به بیمار،از نسبت مردان سالم به بیمار بیشتر است

# %% [markdown]
# #### Outlier Detection & Removal:
# We will filter ouliers using Z-test.

# %% [markdown]
# ![outlier.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Z-test formula:
# \begin{equation*}
#     Z = \bigg|\frac {x - mu} {std}\bigg|
# \end{equation*}

# %%
################################################################################
## TODO: Suppose that, based on our prior knowledge, we know some columns have##
## outliers. Calculate z-score for each featuer and determine the outliers    ##
## with threshold=3, then eliminate them. Target dataframe has(1173,12)shape. ##
################################################################################

columns = ["age","resting bp s","cholesterol","max heart rate"]
threshold = 3

df['age_z'] = abs(df['age'] - df['age'].mean())/df['age'].std()
df['resting bp s_z'] = abs(df['resting bp s'] - df['resting bp s'].mean())/df['resting bp s'].std()
df['cholesterol_z'] = abs(df['cholesterol'] - df['cholesterol'].mean())/df['cholesterol'].std()
df['max heart rate_z'] = abs(df['max heart rate']- df['max heart rate'].mean())/df['max heart rate'].std()

df = df[df['age_z'] < threshold]
df = df[df['resting bp s_z']< threshold]
df = df[df['cholesterol_z']< threshold]
df = df[df['max heart rate_z']< threshold]
df = df.drop(["age_z","resting bp s_z","cholesterol_z","max heart rate_z"],axis =1)

df
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# 2                       0            1              98                0
# 3                       0            0             108                1
# 4                       0            0             122                0
# ...                   ...          ...             ...              ...
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 1         1.0         2       1
# 2         0.0         1       0
# 3         1.5         2       1
# 4         0.0         1       0
# ...       ...       ...     ...
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# 1189      0.0         1       0
#
# [1173 rows x 12 columns]

# %% [markdown]
# #### Feature Engineering:
# Sometimes the collected data are raw; they are either incompatible with your model or hinders its performance. That’s when feature engineering comes to rescue. It encompasses preprocessing techniques to compile a dataset by extracting features from raw data.

# %%
################################################################################
## TODO: Normalize numerical features to be between 0 and 1                   ##
## Note that just numerical fetures should be normalized. type of features is ##
## determined in dataset description file.                                    ##
################################################################################
columns = ["age","resting bp s","cholesterol","max heart rate", "oldpeak"]

for column in columns:
    df[column] = (df[column] - df[column].min())/(df[column].max() - df[column].min())

df

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
# Out:
#            age  sex  chest pain type  resting bp s  cholesterol  \
# 0     0.244898    1                2      0.571429     0.588595
# 1     0.428571    0                3      0.761905     0.366599
# 2     0.183673    1                2      0.476190     0.576375
# 3     0.408163    0                4      0.552381     0.435845
# 4     0.530612    1                3      0.666667     0.397149
# ...        ...  ...              ...           ...          ...
# 1185  0.346939    1                1      0.285714     0.537678
# 1186  0.816327    1                4      0.609524     0.393075
# 1187  0.591837    1                4      0.476190     0.266802
# 1188  0.591837    0                2      0.476190     0.480652
# 1189  0.204082    1                3      0.552381     0.356415
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0        0.777778                0
# 1                       0            0        0.659259                0
# 2                       0            1        0.229630                0
# 3                       0            0        0.303704                1
# 4                       0            0        0.407407                0
# ...                   ...          ...             ...              ...
# 1185                    0            0        0.481481                0
# 1186                    1            0        0.548148                0
# 1187                    0            0        0.355556                1
# 1188                    0            2        0.792593                0
# 1189                    0            0        0.785185                0
#
#        oldpeak  ST slope  target
# 0     0.295455         1       0
# 1     0.409091         2       1
# 2     0.295455         1       0
# 3     0.465909         2       1
# 4     0.295455         1       0
# ...        ...       ...     ...
# 1185  0.431818         2       1
# 1186  0.681818         2       1
# 1187  0.431818         2       1
# 1188  0.295455         2       1
# 1189  0.295455         1       0
#
# [1173 rows x 12 columns]

# %% [markdown]
# ### SVM - (60 pts)

# %% [markdown]
# #### spliting data

# %%
# The original dataset labels is 0 and 1 and in the following code we change it to -1 and 1. 
df.target.replace(0 , -1 , inplace = True) 

# Turn pandas dataframe to numpy array type
df = df.to_numpy()

# Splitting data into train and test part. 70% for train and 30% for test
train = df[:int(len(df) * 0.7)]
test = df[int(len(df) * 0.7):]

# Getting features 
X_train = train[: , :-1]
y_train = train[: , -1]

# Getting labels
X_test = test[: , :-1]
y_test = test[: , -1]

# shapes should be: 
# Train: (821, 11) (821,)
# Test: (352, 11) (352,)
print("Train: ", X_train.shape ,y_train.shape)
print("Test: " ,X_test.shape ,y_test.shape)
# Out:
# Train:  (821, 11) (821,)
# Test:  (352, 11) (352,)

# %% [markdown]
# #### SVM Using sklearn:
# Use the standard libarary SVM classifier (SVC) on the training data, and then test the classifier on the test data. You will need to call SVM with 3 kernels: (1) Linear, (2) Polynomial and (3) RBF. You can change C to achive better results. For "RBF" find "gamma" witch takes 90% accuracy, at least. For polynomial kernel you are allowed to change "degree" to find best results.
#
# For each kernel, reportting the followings is required:
# Accuracy, Precision, Recall, F1score.

# %%
def classification_report(y_true, y_pred):
    #################################################################################
    ## TODO: Define a function that returns the followings:                        ##
    ## Accuracy, Precision, Recall, F1score.                                       ##
    #################################################################################
    true = np.equal(y_true,y_pred) 
    false = 1-true
    positive = np.where(y_pred==1)[0]
    negative = np.where(y_pred==-1)[0]
    
    tp = true[positive].sum()
    tn = true[negative].sum()
    fp = false[positive].sum()
    fn = false[negative].sum()
    Accuracy = true.sum()/(true.sum()+false.sum()) 
    Precision = tp/(tp+fp)
    Recall = tp/(tp+fn)
    F1score = 2 * Precision * Recall/(Precision + Recall)
    
    #################################################################################
    #                                 END OF YOUR CODE                              #
    #################################################################################
    return Accuracy, Precision, Recall, F1score

# %%
#########################################################################################
## TODO: Use svm of sklearn package (imported above) with 3 kernels.                   ##
## You should define model, fit using X_train, predict using X_test.                   ##
## your predictions known as y_pred.                                                   ##
## then use classification_report function to evaluate model.                          ##
#########################################################################################

# linear kernel


linear = SVC(kernel = 'linear',C =1 )
linear.fit(X_train, y_train)
y_pred = linear.predict(X_test)
print("results of sklearn svm linear kernel:", classification_report(y_test, y_pred))



# polynomial kernel
polynomial = SVC(kernel = 'poly',C =2 , gamma=1)
polynomial.fit(X_train, y_train)
y_pred = polynomial.predict(X_test)
print("results of sklearn svm polynomial kernel:", classification_report(y_test, y_pred))




# rbf kernel
rbf = SVC(kernel = 'rbf',C =9 , gamma=5)
rbf.fit(X_train, y_train)
y_pred = rbf.predict(X_test)
print("results of sklearn svm RBF kernel:", classification_report(y_test, y_pred))


#########################################################################################
#                                      END OF YOUR CODE                                 #
#########################################################################################
# Out:
# results of sklearn svm linear kernel: (0.7869318181818182, 0.7756410256410257, 0.7515527950310559, 0.7634069400630915)
# results of sklearn svm polynomial kernel: (0.84375, 0.83125, 0.8260869565217391, 0.8286604361370717)
# results of sklearn svm RBF kernel: (0.9119318181818182, 0.90625, 0.9006211180124224, 0.9034267912772586)

# %% [markdown]
# #### SVM:
# Now that you know how the standard library SVM works on the dataset, attempt to implement your own version of SVM. Implement SVM using Quadratic Programming(QP) approach. Remember that SVM objective fuction with QP is:
#
# \begin{equation*}
#     min_{\alpha}\quad\frac{1}{2}\alpha^T\,Q\,\alpha-1^T\,\alpha\\
#     s.t.\qquad y^T\,\alpha=0,\,\alpha\ge0
# \end{equation*}
#
# where:
# \begin{equation*}
#     Q_{i,j}=y_i\,y_j\,\langle x_i\,,\,x_j\rangle
# \end{equation*}
#
# and:
# \begin{equation*}
#     \text{if}\;(\alpha_n>0)\;\text{then}\;x_n\;\text{is a  support vector}
# \end{equation*}
#
# For this perpose, complete the following code. You are allowed to use "cvxopt" package. It's an optimization package for Quadratic Programming. Below is the user's guide for the QP from CVXOPT:
#
# [Quadratic Programming](https://cvxopt.org/userguide/coneprog.html#quadratic-programming)

# %%
# Hide cvxopt output
cvxopt.solvers.options["show_progress"] = False

#####################################################################################
## TODO: Use the information from the lecture slides to formulate the SVM          ##
## kernels. These kernel functions will be called in the SVM class.                ##
#####################################################################################

def linear_kernel():
    pass

def polynomial_kernel():
    pass

def rbf_kernel():
    pass

#####################################################################################
#                                   END OF YOUR CODE                                #
#####################################################################################


class MySVM(object):
    def __init__(self, kernel=linear_kernel, C=None):
        self.kernel = kernel
        self.C = C
        if self.C is not None: self.C = float(self.C)

    def fit(self, X, y):

        n_samples, n_features = X.shape

        #####################################################################################
        ## TODO: Compute Gram matrix "K" for the given kernel.                             ##
        #####################################################################################        
        K = None

        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################


        #####################################################################################
        ## TODO: Setup SVM objective function in QP form (Notation from attached link).    ##
        ## Guidance: G and h have defferent definition if C is used or not.                ##
        #####################################################################################
        P = None
        q = None
        A = None
        b = None
        G = None
        h = None

        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

        # solve QP problem
        solution = cvxopt.solvers.qp(P, q, G, h, A, b)

        # Lagrange multipliers
        alpha = np.ravel(solution['x'])

        # Support vectors have non zero lagrange multipliers
        sv = alpha > 1e-5

        #this will actually give the indices of the support vectors
        ind = np.arange(len(alpha))[sv]

        # get alphas of support vector , Xs and ys too.
        self.alpha = alpha[sv]
        self.sv = X[sv]
        self.sv_y = y[sv]

        #####################################################################################
        ## TODO: Compute the Intercept b and Weight vector w.                              ##
        #####################################################################################
        # Intercept
        self.b = None

        # Weight vector
        if self.kernel == linear_kernel:
            self.w = None
        else:
            self.w = None #Guidance: for non-linear case this should be None. (do not change)
        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

    def predict(self, X):
        if self.w is not None:
            return np.dot(X, self.w) + self.b
        else:
        #####################################################################################
        ## TODO: For non-linear case, implement the kernel trick to predict the label.     ##
        #####################################################################################
            y_predict = None

            return np.sign(y_predict + self.b)

        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

# %%
###################################################################################
## TODO: define 3 model same as previous part (SVM Using sklearn) and evaluate   ##
## them. Note that for comaparing your result with that part for each kernel use ##
## same parameters in both parts.                                                ##
###################################################################################

# linear kernel
mylinear = MySVM()
mylinear.fit(X_train, y_train)
y_pred = mylinear.predict(X_test)
print("results of MySVM linear kernel:", classification_report(y_test , y_pred))


# polynomial kernel

print("results of MySVM polynomial kernel:", classification_report(y_test , y_pred))


# rbf kernel

print("results of Mysvm RBF kernel:", classification_report(y_test , y_pred))
# Out:
# ---------------------------------------------------------------------------
# ArithmeticError                           Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\misc.py in factor(W, H, Df)
#    1428                 if type(F['S']) is matrix:
# -> 1429                     lapack.potrf(F['S'])
#    1430                 else:
#
# ArithmeticError: 25
#
# During handling of the above exception, another exception occurred:
#
# ArithmeticError                           Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\coneprog.py in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    2064         for rti in W['rti']: rti[::rti.size[0]+1 ] = 1.0
# -> 2065         try: f = kktsolver(W)
#    2066         except ArithmeticError:
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\coneprog.py in kktsolver(W)
#    1980          def kktsolver(W):
# -> 1981              return factor(W, P)
#    1982
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\misc.py in factor(W, H, Df)
#    1443                 if type(F['S']) is matrix:
# -> 1444                     lapack.potrf(F['S'])
#    1445                 else:
#
# ArithmeticError: 25
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14316/1673904180.py in <module>
#       7 # linear kernel
#       8 mylinear = MySVM()
# ----> 9 mylinear.fit(X_train, y_train)
#      10 y_pred = mylinear.predict(X_test)
#      11 print("results of MySVM linear kernel:", classification_report(y_test , y_pred))
#
# ~\AppData\Local\Temp/ipykernel_14316/562051692.py in fit(self, X, y)
#      53
#      54         # solve QP problem
# ---> 55         solution = cvxopt.solvers.qp(P, q, G, h, A, b)
#      56
#      57         # Lagrange multipliers
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\coneprog.py in qp(P, q, G, h, A, b, solver, kktsolver, initvals, **kwargs)
#    4483             'residual as dual infeasibility certificate': dinfres}
#    4484
# -> 4485     return coneqp(P, q, G, h, None, A,  b, initvals, kktsolver = kktsolver, options = options)
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\cvxopt\coneprog.py in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    2065         try: f = kktsolver(W)
#    2066         except ArithmeticError:
# -> 2067             raise ValueError("Rank(A) < p or Rank([P; A; G]) < n")
#    2068
#    2069
#
# ValueError: Rank(A) < p or Rank([P; A; G]) < n

# %% [markdown]
# #### Question 2: Report best results.
#
#
#
# 1.  Best kernel:
# 2.  Best Accuracy:

# %% [markdown]
# ### Bonus Score - (10pts)
#
# In this step you can check other kernel functions or change parameters or any idea to get better result in compare with last section's results.
